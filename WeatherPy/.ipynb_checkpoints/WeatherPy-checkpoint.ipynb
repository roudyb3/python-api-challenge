# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
from pprint import pprint

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
#build base URL and query URL
url = 'http://api.openweathermap.org/data/2.5/weather?'
query_url = f'{url}appid={weather_api_key}&q='
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=21595e39f7c13a3649db142ce6774aee&q='

# %%
city_df = pd.DataFrame(cities)
city_df.rename(columns ={city_df.columns[0]:"City"},inplace = True)
city_df
# Out:
#                 City
# 0          jamestown
# 1    les ponts-de-ce
# 2         butaritari
# 3        antofagasta
# 4             albany
# ..               ...
# 603      mitsamiouli
# 604            basco
# 605        ulladulla
# 606            goure
# 607            reyes
#
# [608 rows x 1 columns]

# %%
#create columns to add to the city dataframe to hold it all
city_df["Lat"] = ""
city_df["Lng"] = ""
city_df["Temp"] = ""
city_df["Humidity"] = ""
city_df["Cloudiness"] = ""
city_df["Wind"] = ""
city_df["Country"] = ""
city_df["Date"] = ""
city_df.head()
# Out:
#               City Lat Lng Temp Humidity Cloudiness Wind Country Date
# 0        jamestown
# 1  les ponts-de-ce
# 2       butaritari
# 3      antofagasta
# 4           albany

# %%
#add the api key to the parameter
params = {"q": weather_api_key}

# %%
weather_response = requests.get(query_url + city).json()
weather_response
# Out:
# {'coord': {'lon': -67.3833, 'lat': -14.3167},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 302.24,
#   'feels_like': 303.05,
#   'temp_min': 302.24,
#   'temp_max': 302.24,
#   'pressure': 1017,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 2.06, 'deg': 120},
#  'clouds': {'all': 18},
#  'dt': 1628113526,
#  'sys': {'type': 1,
#   'id': 8630,
#   'country': 'BO',
#   'sunrise': 1628074202,
#   'sunset': 1628115667},
#  'timezone': -14400,
#  'id': 3906478,
#  'name': 'Reyes',
#  'cod': 200}

# %%
# loop through the cities to get all the data we want

for index, row in city_df.iterrows():
    city = row['City']
    params ["q"] = city
    
    weather_response = requests.get(query_url + city).json()
    print(f'Record {index}:{city}')
        
    try:
        city_df.loc[index,'Lat'] = weather_response['coord']['lat']
        city_df.loc[index,'Lng'] = weather_response['coord']['lon']
        city_df.loc[index,'Temp'] = weather_response['main']['temp_max']
        city_df.loc[index,'Humidity'] = weather_response['main']['humidity']
        city_df.loc[index,'Cloudiness']= weather_response['clouds']['all']
        city_df.loc[index,'Wind']= weather_response['wind']['speed']
        city_df.loc[index,'Country']= weather_response['sys']['country']
        city_df.loc[index,'Date']= weather_response['dt']
        
    except(KeyError, SyntaxError):
        print("City not found. Skipping")
# Out:
# Record 0:jamestown
# Record 1:les ponts-de-ce
# Record 2:butaritari
# Record 3:antofagasta
# Record 4:albany
# Record 5:touros
# Record 6:jacareacanga
# Record 7:luderitz
# Record 8:barentsburg
# City not found. Skipping
# Record 9:lebu
# Record 10:thames
# Record 11:clyde river
# Record 12:cape town
# Record 13:praya
# Record 14:lorengau
# Record 15:leningradskiy
# Record 16:nizhneyansk
# City not found. Skipping
# Record 17:upernavik
# Record 18:amderma
# City not found. Skipping
# Record 19:carnarvon
# Record 20:barrow
# Record 21:tekeli
# Record 22:ponferrada
# Record 23:maple creek
# Record 24:bluff
# Record 25:bambous virieux
# Record 26:mount gambier
# Record 27:arraial do cabo
# Record 28:marsa matruh
# Record 29:okhotsk
# Record 30:wyszkow
# Record 31:bajil
# Record 32:aurad
# Record 33:mys shmidta
# City not found. Skipping
# Record 34:soyo
# Record 35:codrington
# Record 36:khorixas
# Record 37:muisne
# Record 38:koumac
# Record 39:avera
# Record 40:bredasdorp
# Record 41:arlit
# Record 42:egvekinot
# Record 43:opuwo
# Record 44:maldonado
# Record 45:rikitea
# Record 46:bethel
# Record 47:rabak
# Record 48:torbay
# Record 49:bandar penggaram
# City not found. Skipping
# Record 50:busselton
# Record 51:narsaq
# Record 52:mar del plata
# Record 53:hobart
# Record 54:chuy
# Record 55:victoria
# Record 56:mattawa
# Record 57:saint anthony
# Record 58:dikson
# Record 59:georgetown
# Record 60:bengkulu
# Record 61:mataura
# Record 62:punta arenas
# Record 63:tamandare
# Record 64:copiapo
# Record 65:bungoma
# Record 66:hukuntsi
# Record 67:atuona
# Record 68:sao filipe
# Record 69:taolanaro
# City not found. Skipping
# Record 70:tuktoyaktuk
# Record 71:yellowknife
# Record 72:nishihara
# Record 73:abu samrah
# Record 74:thompson
# Record 75:port hedland
# Record 76:haines junction
# Record 77:babayurt
# Record 78:faya
# Record 79:avarua
# Record 80:port elizabeth
# Record 81:tubruq
# City not found. Skipping
# Record 82:ponta do sol
# Record 83:ushuaia
# Record 84:hilo
# Record 85:maceio
# Record 86:tasiilaq
# Record 87:xam nua
# Record 88:nikolskoye
# Record 89:muzhi
# Record 90:port alfred
# Record 91:ahipara
# Record 92:kazanskaya
# Record 93:koslan
# Record 94:kruisfontein
# Record 95:kaitangata
# Record 96:vaini
# Record 97:attawapiskat
# City not found. Skipping
# Record 98:biak
# Record 99:zuwarah
# Record 100:bac lieu
# Record 101:nemuro
# Record 102:illoqqortoormiut
# City not found. Skipping
# Record 103:qingdao
# Record 104:amberley
# Record 105:moita bonita
# Record 106:vila franca do campo
# Record 107:hermanus
# Record 108:novikovo
# Record 109:pevek
# Record 110:hun
# Record 111:dilla
# Record 112:vaitupu
# City not found. Skipping
# Record 113:souillac
# Record 114:la orilla
# Record 115:okha
# Record 116:jojoima
# Record 117:grand gaube
# Record 118:odweyne
# Record 119:vasto
# Record 120:kholodnyy
# Record 121:auki
# Record 122:akdepe
# Record 123:isla mujeres
# Record 124:umea
# Record 125:bazarnyye mataki
# Record 126:moose factory
# Record 127:zlatoustovsk
# City not found. Skipping
# Record 128:puqi
# Record 129:tarbes
# Record 130:khatanga
# Record 131:tarko-sale
# Record 132:taoudenni
# Record 133:villa carlos paz
# Record 134:saint-philippe
# Record 135:hithadhoo
# Record 136:manicore
# Record 137:mercedes
# Record 138:bargal
# City not found. Skipping
# Record 139:cherskiy
# Record 140:hameenlinna
# Record 141:mayskiy
# Record 142:safakulevo
# Record 143:kahului
# Record 144:constitucion
# Record 145:solsvik
# City not found. Skipping
# Record 146:kasongo-lunda
# Record 147:saint george
# Record 148:koshurnikovo
# Record 149:the valley
# Record 150:surskoye
# Record 151:phalaborwa
# Record 152:cayenne
# Record 153:coquimbo
# Record 154:portland
# Record 155:kapaa
# Record 156:new norfolk
# Record 157:samusu
# City not found. Skipping
# Record 158:klaksvik
# Record 159:sibolga
# Record 160:sarangani
# Record 161:bati
# Record 162:castro
# Record 163:kieta
# Record 164:vestmannaeyjar
# Record 165:tual
# Record 166:duluth
# Record 167:belmonte
# Record 168:san rafael
# Record 169:henties bay
# Record 170:qaanaaq
# Record 171:provideniya
# Record 172:fare
# Record 173:east london
# Record 174:mocuba
# Record 175:deh rawud
# City not found. Skipping
# Record 176:esperance
# Record 177:udarnyy
# Record 178:halifax
# Record 179:haicheng
# Record 180:nuevo progreso
# Record 181:sao joao da barra
# Record 182:atasu
# Record 183:sausar
# Record 184:bay roberts
# Record 185:tumannyy
# City not found. Skipping
# Record 186:lavrentiya
# Record 187:cidreira
# Record 188:nome
# Record 189:kita
# Record 190:batemans bay
# Record 191:palabuhanratu
# City not found. Skipping
# Record 192:pangai
# Record 193:santa rosa
# Record 194:cockburn town
# Record 195:lompoc
# Record 196:marsh harbour
# Record 197:airai
# Record 198:kampot
# Record 199:ajdabiya
# Record 200:lima
# Record 201:domna
# Record 202:vao
# Record 203:boda
# Record 204:little current
# Record 205:upington
# Record 206:bathsheba
# Record 207:phan thiet
# Record 208:talnakh
# Record 209:ribeira grande
# Record 210:tuatapere
# Record 211:yunjinghong
# City not found. Skipping
# Record 212:port hardy
# Record 213:ancud
# Record 214:san luis
# Record 215:diebougou
# Record 216:lasa
# Record 217:thunder bay
# Record 218:yulara
# Record 219:luganville
# Record 220:quatre cocos
# Record 221:karistos
# City not found. Skipping
# Record 222:san patricio
# Record 223:nabire
# Record 224:cimarron hills
# Record 225:mecca
# Record 226:narasannapeta
# Record 227:tselinnoye
# Record 228:acajutla
# Record 229:hailey
# Record 230:pemangkat
# Record 231:severo-kurilsk
# Record 232:trinidad
# Record 233:palauig
# Record 234:sur
# Record 235:guapo
# Record 236:pangnirtung
# Record 237:marawi
# Record 238:mattru
# Record 239:los algarrobos
# Record 240:moyale
# Record 241:afgoye
# City not found. Skipping
# Record 242:hobyo
# Record 243:tura
# Record 244:geraldton
# Record 245:soller
# Record 246:puerto ayora
# Record 247:ugoofaaru
# Record 248:yei
# Record 249:north bend
# Record 250:ringas
# Record 251:ino
# Record 252:porangatu
# Record 253:zhangjiakou
# Record 254:sunndalsora
# Record 255:alofi
# Record 256:idlib
# Record 257:nouadhibou
# Record 258:kavieng
# Record 259:palasa
# Record 260:sept-iles
# Record 261:gurgan
# City not found. Skipping
# Record 262:garowe
# Record 263:sheridan
# Record 264:pisco
# Record 265:indiaroba
# Record 266:cabo san lucas
# Record 267:vanimo
# Record 268:abu kamal
# Record 269:roald
# Record 270:iracoubo
# Record 271:sentyabrskiy
# City not found. Skipping
# Record 272:sandpoint
# Record 273:benjamin constant
# Record 274:navahrudak
# Record 275:saanen
# Record 276:ruteng
# Record 277:bayanday
# Record 278:yaan
# Record 279:mahebourg
# Record 280:saint-pierre
# Record 281:hualmay
# Record 282:aflu
# City not found. Skipping
# Record 283:tibati
# Record 284:shache
# Record 285:siyabuswa
# Record 286:bereda
# Record 287:baihar
# Record 288:seymchan
# Record 289:port lincoln
# Record 290:paamiut
# Record 291:baykit
# Record 292:mullaitivu
# City not found. Skipping
# Record 293:poum
# Record 294:deputatskiy
# Record 295:viedma
# Record 296:alta floresta
# Record 297:saskylakh
# Record 298:grahamstown
# Record 299:khani
# Record 300:ixtapa
# Record 301:meulaboh
# Record 302:grafton
# Record 303:comodoro rivadavia
# Record 304:mogadishu
# Record 305:liling
# Record 306:saleaula
# City not found. Skipping
# Record 307:norman wells
# Record 308:tanhacu
# Record 309:makakilo city
# Record 310:pekan
# Record 311:ambon
# Record 312:acapulco
# Record 313:lae
# Record 314:southbridge
# Record 315:ndioum
# Record 316:kaka
# Record 317:ceres
# Record 318:san isidro
# Record 319:hasaki
# Record 320:kuche
# City not found. Skipping
# Record 321:chokurdakh
# Record 322:turukhansk
# Record 323:jumla
# Record 324:omboue
# Record 325:esfarayen
# Record 326:alice springs
# Record 327:vittoria
# Record 328:fortuna
# Record 329:artyk
# City not found. Skipping
# Record 330:kampong thum
# Record 331:iqaluit
# Record 332:emerald
# Record 333:taburi
# City not found. Skipping
# Record 334:anyksciai
# Record 335:porto novo
# Record 336:pital
# Record 337:utiroa
# City not found. Skipping
# Record 338:ayan
# Record 339:necochea
# Record 340:port augusta
# Record 341:tabou
# Record 342:longyearbyen
# Record 343:sembakung
# Record 344:almeria
# Record 345:kodiak
# Record 346:atar
# Record 347:fairfield
# Record 348:jardim
# Record 349:nanortalik
# Record 350:sataua
# City not found. Skipping
# Record 351:sucua
# Record 352:price
# Record 353:beringovskiy
# Record 354:great yarmouth
# Record 355:sisimiut
# Record 356:tautira
# Record 357:torbat-e jam
# Record 358:newport beach
# Record 359:kudahuvadhoo
# Record 360:mackay
# Record 361:pedernales
# Record 362:tawnat
# City not found. Skipping
# Record 363:richards bay
# Record 364:raiganj
# Record 365:aswan
# Record 366:belushya guba
# City not found. Skipping
# Record 367:abong mbang
# Record 368:grindavik
# Record 369:pochinki
# Record 370:walvis bay
# Record 371:marcona
# City not found. Skipping
# Record 372:maxixe
# Record 373:buraydah
# Record 374:kaoma
# Record 375:vila
# Record 376:umzimvubu
# City not found. Skipping
# Record 377:mahadday weyne
# City not found. Skipping
# Record 378:morogoro
# Record 379:dzemul
# Record 380:ati
# Record 381:faanui
# Record 382:blackwater
# Record 383:ondjiva
# Record 384:yar-sale
# Record 385:teya
# Record 386:husavik
# Record 387:ust-ordynskiy
# Record 388:pafos
# Record 389:ndjole
# Record 390:jiaozuo
# Record 391:rawson
# Record 392:toliary
# City not found. Skipping
# Record 393:abu dhabi
# Record 394:liku
# Record 395:otane
# Record 396:isangel
# Record 397:brigantine
# Record 398:pacific grove
# Record 399:saiha
# Record 400:mehamn
# Record 401:sajanan
# Record 402:cairns
# Record 403:saldanha
# Record 404:boguchany
# Record 405:maun
# Record 406:molochnoye
# Record 407:kawalu
# Record 408:svetlyy
# Record 409:chilca
# Record 410:kayasula
# Record 411:takoradi
# Record 412:batagay-alyta
# Record 413:kaunas
# Record 414:tiksi
# Record 415:muros
# Record 416:tsihombe
# City not found. Skipping
# Record 417:santa ines
# Record 418:namatanai
# Record 419:kavaratti
# Record 420:aransas pass
# Record 421:innisfail
# Record 422:san ignacio
# Record 423:nuuk
# Record 424:sechura
# Record 425:umm kaddadah
# Record 426:tonantins
# Record 427:petropavlovskoye
# Record 428:arman
# Record 429:malwan
# City not found. Skipping
# Record 430:collierville
# Record 431:banjar
# Record 432:sitka
# Record 433:belaya gora
# Record 434:torrington
# Record 435:evensk
# Record 436:kisangani
# Record 437:zeya
# Record 438:plover
# Record 439:ndele
# Record 440:mananara
# Record 441:hofn
# Record 442:florianopolis
# Record 443:denpasar
# Record 444:soligalich
# Record 445:kimbe
# Record 446:corcoran
# Record 447:krasnyy chikoy
# Record 448:dicabisagan
# Record 449:kilindoni
# Record 450:la crosse
# Record 451:shingu
# Record 452:saint-nazaire
# Record 453:waipawa
# Record 454:ketchikan
# Record 455:de-kastri
# Record 456:priargunsk
# Record 457:araouane
# Record 458:tazovskiy
# Record 459:magadan
# Record 460:rundu
# Record 461:pathein
# Record 462:byron bay
# Record 463:suzu
# City not found. Skipping
# Record 464:thinadhoo
# Record 465:cabedelo
# Record 466:kichmengskiy gorodok
# Record 467:pierre
# Record 468:marfino
# Record 469:sri aman
# Record 470:dalhousie
# Record 471:kalmunai
# Record 472:fairbanks
# Record 473:sanmenxia
# Record 474:labuhan
# Record 475:tukrah
# Record 476:garmsar
# Record 477:san quintin
# Record 478:kamiiso
# Record 479:katsuura
# Record 480:buala
# Record 481:batsfjord
# Record 482:uyemskiy
# Record 483:ban nahin
# Record 484:samarai
# Record 485:lazaro cardenas
# Record 486:kutulik
# Record 487:saint-louis
# Record 488:nioki
# Record 489:pleasanton
# Record 490:metehara
# City not found. Skipping
# Record 491:colquechaca
# Record 492:marsabit
# Record 493:broome
# Record 494:bundaberg
# Record 495:butembo
# Record 496:ilanskiy
# Record 497:jaguey grande
# Record 498:yangjiang
# Record 499:nakambala
# Record 500:caravelas
# Record 501:bilibino
# Record 502:yermakovskoye
# Record 503:orlik
# Record 504:hamilton
# Record 505:jiddah
# City not found. Skipping
# Record 506:mount isa
# Record 507:puerto carreno
# Record 508:te anau
# Record 509:bosaso
# Record 510:bonthe
# Record 511:oga
# Record 512:neuquen
# Record 513:cabra
# Record 514:lolua
# City not found. Skipping
# Record 515:amuntai
# Record 516:natal
# Record 517:belyy yar
# Record 518:angoche
# Record 519:laguna
# Record 520:lucapa
# Record 521:korla
# Record 522:payo
# Record 523:arroio grande
# Record 524:mrirt
# City not found. Skipping
# Record 525:kununurra
# Record 526:sistranda
# Record 527:kelowna
# Record 528:gizo
# Record 529:iquitos
# Record 530:bilma
# Record 531:troina
# Record 532:mulege
# Record 533:port blair
# Record 534:ipatovo
# Record 535:bucerias
# Record 536:wewak
# Record 537:trincomalee
# Record 538:shitanjing
# Record 539:christchurch
# Record 540:vallenar
# Record 541:noumea
# Record 542:tabuk
# Record 543:vila velha
# Record 544:koungheul
# Record 545:tuy hoa
# Record 546:dzhalil
# Record 547:jinka
# Record 548:gayeri
# Record 549:cukai
# Record 550:dingle
# Record 551:seaham
# Record 552:tupik
# Record 553:fernie
# Record 554:saint-francois
# Record 555:katakwi
# Record 556:hamamatsu
# Record 557:saint-augustin
# Record 558:iseyin
# Record 559:diffa
# Record 560:miguel auza
# Record 561:manta
# Record 562:preston
# Record 563:turiacu
# Record 564:varena
# Record 565:toftir
# City not found. Skipping
# Record 566:benidorm
# Record 567:presidencia roque saenz pena
# Record 568:naze
# Record 569:grand river south east
# City not found. Skipping
# Record 570:steinbach
# Record 571:puerto escondido
# Record 572:salinopolis
# Record 573:goderich
# Record 574:araxa
# Record 575:lahij
# Record 576:estacion coahuila
# Record 577:bolshevik
# Record 578:kindu
# Record 579:pundaguitan
# Record 580:salalah
# Record 581:marystown
# Record 582:stornoway
# Record 583:qiongshan
# Record 584:gobabis
# Record 585:jiuquan
# Record 586:doctor pedro p. pena
# City not found. Skipping
# Record 587:ostrovnoy
# Record 588:manono
# Record 589:dwarka
# Record 590:culebra
# Record 591:westport
# Record 592:komsomolskiy
# Record 593:mandera
# Record 594:adrar
# Record 595:dumas
# Record 596:puerto lempira
# Record 597:radishchevo
# Record 598:lamu
# Record 599:lagoa
# Record 600:teeli
# Record 601:clarence town
# Record 602:mizan teferi
# Record 603:mitsamiouli
# Record 604:basco
# Record 605:ulladulla
# Record 606:goure
# Record 607:reyes

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df.to_csv("Resources/output.csv", index=False)

# %%
#create a dataframe to hold it all
city_df.head()
# Out:
#               City      Lat       Lng    Temp Humidity Cloudiness  Wind  \
# 0        jamestown   42.097  -79.2353  298.92       46          1  3.09
# 1  les ponts-de-ce  47.4231   -0.5248   290.4       99         89  2.53
# 2       butaritari   3.0707  172.7902  301.14       66         83  3.88
# 3      antofagasta   -23.65     -70.4  287.75       64         13  1.66
# 4           albany  42.6001  -73.9662  299.51       56        100  1.38
#
#   Country        Date
# 0      US  1628113268
# 1      FR  1628113527
# 2      KI  1628113528
# 3      CL  1628113492
# 4      US  1628113529

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df['Humidity']= pd.to_numeric(city_df["Humidity"])
humidity_sort = city_df.sort_values(by='Humidity', ascending = False)
humidity_sort.head()
# Out:
#               City      Lat       Lng    Temp  Humidity Cloudiness  Wind  \
# 469       sri aman   1.2376  111.4621  296.18     100.0         99  0.51
# 454      ketchikan  55.3422 -131.6461  289.41     100.0         90  5.66
# 26   mount gambier -37.8333  140.7667   281.1     100.0         40  3.09
# 11     clyde river  70.4692  -68.5914  276.28     100.0         90  4.63
# 286         bereda  43.2686   -7.5406  289.21      99.0         11  0.89
#
#     Country        Date
# 469      MY  1628113807
# 454      US  1628113679
# 26       AU  1628113546
# 11       CA  1628113535
# 286      ES  1628113711

# %%
city_df['Temp']= pd.to_numeric(city_df['Temp'])
city_df['Lat']= pd.to_numeric(city_df['Lat'])
city_df['Cloudiness']= pd.to_numeric(city_df['Cloudiness'])
city_df['Wind']= pd.to_numeric(city_df['Wind'])

# %%
#  Get the indices of cities that have humidity over 100%.
# no indices have humidity over 100% thankfully

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Create a scatter plot for lat v. temp
plt.scatter(city_df["Lat"],city_df["Temp"],facecolors = "darkblue", edgecolors = "black", alpha = .85)

#set labels
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#set title
plt.title("City Latitude vs. Max Temperature")

#set a grid so it looks nicer
plt.grid(linestyle='-',linewidth = .75, alpha = .5)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Create a scatter plot for lat v. temp
plt.scatter(city_df["Lat"],city_df["Humidity"],facecolors = "darkblue", edgecolors = "black", alpha = .85)

#set labels
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

#set title
plt.title("City Latitude vs. Humidity")

#set a grid so it looks nicer
plt.grid(linestyle='-',linewidth = .75, alpha = .5)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Create a scatter plot for lat v. temp
plt.scatter(city_df["Lat"],city_df["Cloudiness"],facecolors = "darkblue", edgecolors = "black", alpha = .85)

#set labels
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

#set title
plt.title("City Latitude vs. Cloudiness")

#set a grid so it looks nicer
plt.grid(linestyle='-',linewidth = .75, alpha = .5)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Create a scatter plot for lat v. temp
plt.scatter(city_df["Lat"],city_df["Wind"],facecolors = "darkblue", edgecolors = "black", alpha = .85)

#set labels
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")

#set title
plt.title("City Latitude vs. Wind Speed")

#set a grid so it looks nicer
plt.grid(linestyle='-',linewidth = .75, alpha = .5)

# %% [markdown]
# ## Linear Regression

# %%
#set Northern Hemisphere by filtering to Lat at -
plt.xlim(0, 80)

#Create a scatter plot for lat v. temp
plt.scatter(city_df["Lat"],city_df["Temp"],facecolors = "darkblue", edgecolors = "black", alpha = .85)

#set labels
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#set title
plt.title("City Latitude vs. Max Temperature")

#set a grid so it looks nicer
plt.grid(linestyle='-',linewidth = .75, alpha = .5)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy import stats
from scipy.stats import linregress

# %%
n_hemisphere = city_df.loc[city_df["Lat"] >= 0]
n_hemisphere_df = n_hemisphere["Lat"]
temp = n_hemisphere["Temp"]

# %%
(temp_slope, temp_int, temp_r, temp_p, tem_std_err) = linregress(n_hemisphere_df, temp)

# %%
regression_fit = temp_slope*n_hemisphere_df + temp_int

# %%
plt.scatter(n_hemisphere_df, temp)
plt.plot(n_hemisphere_df, regression_fit, "r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temp')
plt.title("Northern Hemisphere - Max Temp v. lat Lin Regression")
# Out:
# Text(0, 0.5, 'Maximum Temp')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_hemisphere = city_df.loc[city_df["Lat"]<=0]
s_hemisphere_df = s_hemisphere["Lat"]
s_temp = s_hemisphere["Temp"]

# %%
(s_slope, s_int, s_r, s_p, s_std_err) = linregress(s_hemisphere_df, s_temp)
s_regression_fit = s_slope * s_hemisphere_df + s_int

# %%
plt.scatter(s_hemisphere_df, s_temp)
plt.plot(s_hemisphere_df, s_regression_fit, "r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere - Max Temp v. lat Lin Regression")
# Out:
# Text(0.5, 1.0, 'Souther Hemisphere - Max Temp v. lat Lin Regression')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
